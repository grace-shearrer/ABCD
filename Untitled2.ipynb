# %%
import pickle

with open('/Users/gracer/Google Drive/ABCD/important_txt/male_data2.pickle', 'rb') as handle:
    b = pickle.load(handle)

print  b

# %%
import pandas as pd

# %%
data=pd.read_table('/Users/gracer/Google Drive/MetX/brainnet/ov_rich_nod.node.txt', sep='\t', header = None)

# %%
b['FINAL'].shape
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-19-15d42ad6c953> in <module>()
# ----> 1 b['FINAL'].shape
#
# AttributeError: 'list' object has no attribute 'shape'

# %%
data
# Out:
#         0      1     2  3      4            5
# 0   -42.3  -32.6  64.1  0  142.1      L_1_ROI
# 1   -24.5  -37.9  57.0  0  145.1      L_2_ROI
# 2    -8.9  -33.2  45.6  0  122.2    L_23c_ROI
# 3    -4.1  -13.2  53.8  0   86.6   L_24dd_ROI
# 4   -66.6    1.3  19.3  0  133.0     L_3a_ROI
# 5   -56.9  -11.5  46.3  0  138.2     L_3b_ROI
# 6   -40.1   -9.1  63.2  0  142.4      L_4_ROI
# 7   -65.7    5.4  11.0  0   78.7     L_43_ROI
# 8   -42.1   53.9  24.8  0   75.7     L_46_ROI
# 9   -11.9  -45.4  76.4  0   85.9     L_5L_ROI
# 10   -7.0  -37.7  71.4  0   77.5     L_5m_ROI
# 11   -8.5  -42.6  63.0  0  120.7    L_5mv_ROI
# 12  -21.3    7.1  72.6  0  112.2     L_6a_ROI
# 13  -12.6   -9.9  76.1  0   83.6    L_6mp_ROI
# 14  -19.3  -49.5  76.6  0  108.6    L_7AL_ROI
# 15  -11.2  -61.2  67.3  0  100.2    L_7Am_ROI
# 16  -31.5  -54.1  73.6  0  116.4    L_7PC_ROI
# 17  -14.7  -71.1  63.5  0   77.9    L_7PL_ROI
# 18  -65.2  -24.7   0.4  0  105.4     L_A4_ROI
# ...

# %%
data.to_csv('/Users/gracer/Google Drive/MetX/brainnet/ov_rich.node.txt', sep='\t', index = False)
